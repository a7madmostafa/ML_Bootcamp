# %%
# pip install python-dotenv
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Requirement already satisfied: python-dotenv in c:\users\ahmad\anaconda3\lib\site-packages (0.21.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
from dotenv import load_dotenv

load_dotenv()  
api_key = os.getenv("API_KEY")
if api_key:
    print("API Key loaded successfully.")
else:
    print("Failed to load API Key. Please check your .env file.")
# Out:
# API Key loaded successfully.

# %%
import requests

keyword = 'AI'
country = 'us'
url = f"https://newsapi.org/v2/top-headlines?q={keyword}&country={country}&apiKey={api_key}"
response = requests.get(url)
response.status_code
# Out:
# 200

# %%
response.json()
# Out:
# {'status': 'ok',
#  'totalResults': 13,
#  'articles': [{'source': {'id': 'business-insider',
#     'name': 'Business Insider'},
#    'author': 'Kwan Wei Kevin Tan',
#    'title': "Elon Musk fires back at Trump's claim that his companies will still enjoy subsidies - Business Insider",
#    'description': 'The president said in a Truth Social post that he wanted Musk\'s businesses to "THRIVE like never before."',
#    'url': 'https://www.businessinsider.com/musk-slams-trump-claim-his-companies-will-still-get-subsidies-2025-7',
#    'urlToImage': 'https://i.insider.com/6882e2db3d5881a51c1df87e?width=1200&format=jpeg',
#    'publishedAt': '2025-07-25T04:34:00Z',
#    'content': "President Donald Trump said on Thursday that he wouldn't touch the federal subsidies Elon Musk's companies were enjoying because he wanted Musk to continue to prosper.\r\nMusk, however, begs to differ.… [+3482 chars]"},
#   {'source': {'id': None, 'name': 'NPR'},
#    'author': '',
#    'title': 'President Trump takes aim at college sports with a new executive order - NPR',
#    'description': 'The order aims to ban "pay-for-play" NIL deals, mandates scholarships for women\'s and Olympic sports and threatens to withhold funds from schools who don\'t comply. But its legality is in question.',
#    'url': 'https://www.npr.org/2025/07/25/nx-s1-5479194/college-sports-executive-order-trump-eo',
#    'urlToImage': 'https://npr.brightspotcdn.com/dims3/default/strip/false/crop/6000x3375+0+0/resize/1400/quality/100/format/jpeg/?url=http%3A%2F%2Fnpr-brightspot.s3.amazonaws.com%2F9e%2F44%2F6708bcb54ed5b50270360f31bbb0%2Fgettyimages-2210278090.jpg',
#    'publishedAt': '2025-07-25T04:01:00Z',
#    'content': 'WASHINGTON President Trump has taken aim at college sports with a new executive order\r\n signed Thursday that seeks to empower federal agencies, including the U.S. Department of Education, which disbu… [+6140 chars]'},
#   {'source': {'id': None, 'name': 'NBCSports.com'},
#    'author': 'Mike Florio',
#    'title': 'Aaron Rodgers on his INT: "I\'m gonna throw some picks, but I\'m gonna throw some touchdowns, too" - NBC Sports',
#    'description': 'In the first throw of his first team period at his first Steelers training-camp practice, quarterback Aaron Rodgers threw an interception.',
#    'url': 'https://www.nbcsports.com/nfl/profootballtalk/rumor-mill/news/aaron-rodgers-on-his-int-im-gonna-throw-some-picks-but-im-gonna-throw-some-touchdowns-too',
#    'urlToImage': 'https://nbcsports.brightspotcdn.com/dims4/default/e7a9fe9/2147483647/strip/true/crop/4255x2393+0+0/resize/1440x810!/quality/90/?url=https%3A%2F%2Fnbc-sports-production-nbc-sports.s3.us-east-1.amazonaws.com%2Fbrightspot%2F9c%2F39%2Fb2eda8174c98a417964712a25ae0%2Fhttps-api-imagn.com%2Frest%2Fdownload%2FimageID%3D26702632',
#    'publishedAt': '2025-07-25T03:26:34Z',
#    'content': 'In the first throw of his first team period at his first Steelers training-camp practice, quarterback Aaron Rodgers threw an interception. At his first training-camp press conference at St. Vincents … [+927 chars]'},
#   {'source': {'id': 'nbc-news', 'name': 'NBC News'},
#    'author': 'Chloe Atkins, Michael Kosnar, Nnamdi Egwuonwu',
#    'title': 'Trump administration sues New York over sanctuary city policies - NBC News',
#    'description': 'The Trump administration sued New York City on Thursday over its “sanctuary” laws, continuing a monthslong effort to crack down on localities that try to shield undocumented immigrants from federal detainment efforts.“New York City has released thousands of c…',
#    'url': 'https://www.nbcnews.com/politics/trump-administration/trump-administration-sues-new-york-sanctuary-city-policies-rcna220958',
#    'urlToImage': 'https://media-cldnry.s-nbcnews.com/image/upload/t_nbcnews-fp-1200-630,f_auto,q_auto:best/rockcms/2025-05/250504-donald-trump-wm-532p-c5b879.jpg',
#    'publishedAt': '2025-07-25T00:41:00Z',
#    'content': 'The Trump administration sued New York City on Thursday over its sanctuary laws, continuing a monthslong effort to crack down on localities that try to shield undocumented immigrants from federal det… [+6882 chars]'},
#   {'source': {'id': 'axios', 'name': 'Axios'},
#    'author': 'Sareen Habeshian',
#    'title': 'Deputy attorney general meets with Epstein associate Ghislaine Maxwell - Axios',
#    'description': "The deputy AG's interview with the Epstein associate will continue tomorrow, he said.",
#    'url': 'https://www.axios.com/2025/07/25/epstein-maxwell-trump-doj',
#    'urlToImage': 'https://images.axios.com/d_DJtfGMzEDjXNNU6sc3KDn5zgE=/0x289:4000x2539/1366x768/2025/07/25/1753402055419.jpeg',
#    'publishedAt': '2025-07-25T00:39:14Z',
#    'content': 'Driving the news: "Today, I met with Ghislaine Maxwell, and I will continue my interview of her tomorrow" Blanche said in a post on X. \r\n<ul><li>"The Department of Justice will share additional infor… [+1032 chars]'},
#   {'source': {'id': None, 'name': 'BBC News'},
#    'author': None,
#    'title': "Great Recall Taiwan: The vote targeting 'pro-China' lawmakers - BBC",
#    'description': 'The spectre of Chinese influence in parliament has sparked a movement and fractured Taiwan’s society.',
#    'url': 'https://www.bbc.com/news/articles/c5yg1yn082go',
#    'urlToImage': 'https://ichef.bbci.co.uk/news/1024/branded_news/f62b/live/a7a71180-68ec-11f0-85df-6bf58cb3272e.jpg',
#    'publishedAt': '2025-07-24T22:51:11Z',
#    'content': "Tessa Wong\r\nTaiwan's legislators have engaged in brawls in parliament in recent months amid a heated political deadlock\r\nFor most of his life, Deng Pu didn't see himself as an activist but that chang… [+9978 chars]"},
#   {'source': {'id': None, 'name': 'Live Science'},
#    'author': 'Elana Spivack',
#    'title': "Astronomers discover new dwarf planet 'Ammonite' — and it could upend the existence of Planet Nine - Live Science",
#    'description': "A newly discovered dwarf planet called 'Ammonite' (2023 KQ14) has been spotted in the outer solar system, and it could be another nail in the coffin of the Planet Nine hypothesis.",
#    'url': 'https://www.livescience.com/space/planets/astronomers-discover-new-dwarf-planet-ammonite-and-it-could-upend-the-existence-of-planet-nine',
#    'urlToImage': 'https://cdn.mos.cms.futurecdn.net/EribzYMeXuz5wB6Y5XMBPM.jpg',
#    'publishedAt': '2025-07-24T20:09:35Z',
#    'content': "Astronomers have discovered a possible new dwarf planet orbiting far beyond Pluto. First detected in March 2023 by Japan's Subaru Telescope in Hawaii, this object has been dubbed 2023 KQ14 and nickna… [+4227 chars]"},
#   {'source': {'id': None, 'name': 'Live Science'},
#    'author': 'Kristina Killgrove',
#    'title': 'Ancient human relative cannibalized toddlers, 850,000-year-old neck bone reveals - Live Science',
#    'description': "Cut marks on a child's cervical vertebra found at Atapuerca in Spain suggests Homo antecessor was indiscriminate about cannibalism victims.",
#    'url': 'https://www.livescience.com/archaeology/human-evolution/ancient-human-relative-cannibalized-toddlers-850-000-year-old-neck-bone-reveals',
#    'urlToImage': 'https://cdn.mos.cms.futurecdn.net/kfjKnCPHZLHbpgN9HYQ22k.png',
#    'publishedAt': '2025-07-24T18:30:10Z',
#    'content': 'Around 850,000 years ago, a toddler was decapitated and cannibalized, cut marks on one of their neck bones suggest.\r\nThe bone, which belonged to an archaic human relative, was found at the Gran Dolin… [+3323 chars]'},
#   {'source': {'id': None, 'name': 'Forbes'},
#    'author': 'Ty Roush',
#    'title': 'Musk Loses $17 Billion After Tesla’s Historic Revenue Drop - Forbes',
#    'description': 'Musk said his automaker “probably could have a few rough quarters” ahead as federal electric vehicle credits expire soon.',
#    'url': 'https://www.forbes.com/sites/tylerroush/2025/07/24/elon-musks-net-worth-drops-17-billion-as-tesla-shares-plunge/',
#    'urlToImage': 'https://imageio.forbes.com/specials-images/imageserve/688238d0b14f113976eb0e2b/0x0.jpg?format=jpg&height=900&width=1600&fit=bounds',
#    'publishedAt': '2025-07-24T17:18:00Z',
#    'content': 'Shares of Tesla plunged Thursday morning, accounting for a more than $17 billion cut to Elon Musks net worth, after Musk warned his automaker would likely have a few rough quarters ahead as federal e… [+3214 chars]'},
#   {'source': {'id': 'the-wall-street-journal',
#     'name': 'The Wall Street Journal'},
#    'author': 'The Wall Street Journal',
#    'title': 'Beijing’s Trade Tactics, Ukraine Stance Cast Pall Over Europe-China Ties - The Wall Street Journal',
#    'description': None,
#    'url': 'https://www.wsj.com/world/beijings-trade-tactics-ukraine-stance-cast-pall-over-europe-china-ties-3cb35230',
#    'urlToImage': None,
#    'publishedAt': '2025-07-24T14:36:00Z',
#    'content': None},
#   {'source': {'id': 'ars-technica', 'name': 'Ars Technica'},
#    'author': 'Stephen Clark',
#    'title': 'SpaceX launches a pair of NASA satellites to probe the origins of space weather - Ars Technica',
#    'description': '“This is going to really help us understand how to predict space weather in the magnetosphere.”…',
#    'url': 'https://arstechnica.com/space/2025/07/spacex-launches-a-pair-of-nasa-satellites-to-probe-the-origins-of-space-weather/',
#    'urlToImage': 'https://cdn.arstechnica.net/wp-content/uploads/2025/07/solarwind_magneto-1152x648.jpg',
#    'publishedAt': '2025-07-24T12:12:09Z',
#    'content': None}]}

# %%
import requests

def get_top_headlines(api_key, keyword="technology", country="us"):
    url = "https://newsapi.org/v2/top-headlines"
    params = {
        "q": keyword,
        "country": country,
        "apiKey": api_key
    }

    response = requests.get(url, params=params)

    if response.status_code == 200:
        data = response.json()
        articles = data.get("articles", [])
        
        if not articles:
            print("No articles found.")
            return

        for i, article in enumerate(articles[:10], start=1):  # Show top 10
            print(f"\n📰 Headline {i}")
            print("Title:", article["title"])
            print("Source:", article["source"]["name"])
            print("URL:", article["url"])
    else:
        print("Error:", response.status_code)

# %%
# Example usage
keyword = input("Enter a keyword (e.g., AI, sports, economy): ")
get_top_headlines(api_key, keyword)
# Out:
# Enter a keyword (e.g., AI, sports, economy):  sport
# 📰 Headline 1
# Title: President Trump takes aim at college sports with a new executive order - NPR
# Source: NPR
# URL: https://www.npr.org/2025/07/25/nx-s1-5479194/college-sports-executive-order-trump-eo
#
# 📰 Headline 2
# Title: Aaron Rodgers on his INT: "I'm gonna throw some picks, but I'm gonna throw some touchdowns, too" - NBC Sports
# Source: NBCSports.com
# URL: https://www.nbcsports.com/nfl/profootballtalk/rumor-mill/news/aaron-rodgers-on-his-int-im-gonna-throw-some-picks-but-im-gonna-throw-some-touchdowns-too
#
# 📰 Headline 3
# Title: How to watch Liverpool vs AC Milan live, stream link and start time - NBC Sports
# Source: NBCSports.com
# URL: https://www.nbcsports.com/soccer/news/how-to-watch-liverpool-vs-ac-milan-live-stream-link-and-start-time

# %%
# Example usage
country = input("Enter a country code (e.g., us, gb, in): ")
get_top_headlines(api_key, country)
# Out:
# 📰 Headline 1
# Title: ‘I Know What You Did Last Summer’ Twists & Cameos Revealed — Who Is The Fisherman? - Deadline
# Source: Deadline
# URL: http://deadline.com/2025/07/i-know-what-you-did-last-summer-twists-cameos-revealed-1236462871/
#
# 📰 Headline 2
# Title: ‘Fantastic Four’ First Reactions Say Film Is One of the ‘Best Things Marvel Has Ever Made’ With ‘Stunning Visuals’ and ‘Excellent’ Performances From Leading Cast - Variety
# Source: Variety
# URL: https://variety.com/2025/film/news/fantastic-four-first-reactions-pedro-pascal-marvel-1236465177/
#
# 📰 Headline 3
# Title: Gabbard threatens Obama officials with criminal referral over 2016 election assessment - CNN
# Source: CNN
# URL: https://www.cnn.com/2025/07/19/politics/gabbard-threatens-obama-officials-2016-election
#
# 📰 Headline 4
# Title: Man dies after large chain necklace pulls him into MRI machine - AP News
# Source: Associated Press
# URL: https://apnews.com/article/mri-machine-long-island-chain-necklace-4126620d358e3d6b73d145d32ab72852
#
# 📰 Headline 5
# Title: Trump sues Wall Street Journal and Rupert Murdoch over story reporting on Epstein ties - PBS
# Source: PBS
# URL: https://www.pbs.org/newshour/politics/trump-sues-wall-street-journal-and-rupert-murdoch-over-story-reporting-on-epstein-ties
#
# 📰 Headline 6
# Title: Why the Federal Reserve’s Building Renovation Costs $2.5 Billion - Bloomberg.com
# Source: Bloomberg
# URL: https://www.bloomberg.com/news/articles/2025-07-19/trump-s-attacking-powell-over-fed-renovation-here-s-why-it-costs-2-5-billion
#
# 📰 Headline 7
# Title: 30 Injured After Vehicle Drives Into Nightclub Crowd In Los Angeles - Forbes
# Source: Forbes
# URL: https://www.forbes.com/sites/antoniopequenoiv/2025/07/19/30-injured-after-vehicle-drives-into-nightclub-crowd-in-los-angeles/
#
# 📰 Headline 8
# Title: The Open 2025 leaderboard live updates: Golf scores, Open Championship coverage, Round 3 at Royal Portrush - CBS Sports
# Source: CBS Sports
# URL: https://www.cbssports.com/golf/news/the-open-2025-leaderboard-live-updates-golf-scores-open-championship-coverage-round-3-at-royal-portrush/live/
#
# 📰 Headline 9
# Title: Gene therapy maker Sarepta tells FDA it won’t halt shipments despite patient deaths - AP News
# Source: Associated Press
# URL: https://apnews.com/article/sarepta-muscular-dystophy-death-fda-gene-therapy-756b7ef43591b685fc197d6acb29c4c1
#
# 📰 Headline 10
# Title: Women feel more anger as they age, but show it less, study suggests - The Washington Post
# Source: The Washington Post
# URL: https://www.washingtonpost.com/health/2025/07/19/women-anger-menopause-study/

# %%
# Example usage
keyword = input("Enter a keyword (e.g., AI, sports, economy): ")
country = input("Enter a country code (e.g., us, gb, in): ")
get_top_headlines(api_key, keyword, country)
# Out:
# 📰 Headline 1
# Title: Luigi Mangione has an issue with another health insurance company — and it's not UnitedHealthcare - Business Insider
# Source: Business Insider
# URL: https://www.businessinsider.com/aetna-mistakenly-revealed-luigi-mangione-medical-records-defense-2025-7
